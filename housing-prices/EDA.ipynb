# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plots
# %matplotlib inline
df = plots.create_date_cols('data/kc_house_data.csv')
# There are no null values in this data, and all the data is integers or floats
# except date which I converted to a datetime object
print df.columns
# Out:
# Index([u'id', u'date', u'price', u'bedrooms', u'bathrooms', u'sqft_living',
#        u'sqft_lot', u'floors', u'waterfront', u'view', u'condition', u'grade',
#        u'sqft_above', u'sqft_basement', u'yr_built', u'yr_renovated',
#        u'zipcode', u'lat', u'long', u'sqft_living15', u'sqft_lot15', u'day',
#        u'month', u'count'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#         ...         yr_built  yr_renovated       zipcode           lat  \
# count   ...     21613.000000  21613.000000  21613.000000  21613.000000
# mean    ...      1971.005136     84.402258  98077.939805     47.560053
# std     ...        29.373411    401.679240     53.505026      0.138564
# min     ...      1900.000000      0.000000  98001.000000     47.155900
# 25%     ...      1951.000000      0.000000  98033.000000     47.471000
# 50%     ...      1975.000000      0.000000  98065.000000     47.571800
# 75%     ...      1997.000000      0.000000  98118.000000     47.678000
# max     ...      2015.000000   2015.000000  98199.000000     47.777600
#
#                long  sqft_living15     sqft_lot15           day         month  \
# count  21613.000000   21613.000000   21613.000000  21613.000000  21613.000000
# mean    -122.213896    1986.552492   12768.455652     16.688197      6.574423
# std        0.140828     685.391304   27304.179631      8.635063      3.115308
# min     -122.519000     399.000000     651.000000      2.000000      1.000000
# 25%     -122.328000    1490.000000    5100.000000      9.000000      4.000000
# 50%     -122.230000    1840.000000    7620.000000     17.000000      6.000000
# 75%     -122.125000    2360.000000   10083.000000     24.000000      9.000000
# max     -121.315000    6210.000000  871200.000000     32.000000     12.000000
#
#          count
# count  21613.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
#
# [8 rows x 23 columns]

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114727550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1150e2050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11510b750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114726690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111ca1610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c1debd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d47a990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10fcdbf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113611f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113675810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1135db810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112fc4690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114a07c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112fa1c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1146f7e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111c09e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113744e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1147b4e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111d22710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c0bb8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c29b290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11255b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c2aeb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1130c0250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1130eee50>]], dtype=object)

# %%
pd.scatter_matrix(df[df.columns[1:7]],figsize=(16,16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1136c0e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1153436d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115390e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11546d210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112ca0f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112d0ed50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112d93e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112e078d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112e8cd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112e4c550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1154eca10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1155817d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1155f4550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11681c750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116890110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116917210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116971c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a02fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1169c2750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116afbd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116b81b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116bf5890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116c7c710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116ce1f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116d6dfd0>]], dtype=object)

# %%
fig = plt.figure(figsize=(20,20))
for i in range(0,13):
    plots.plot_daily_sales(df, i)
plt.xlabel('Month')
plt.ylabel('Number of Sales')
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
plots.plot_size_change(df)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
plt.hist(np.log(df['price']))
plt.tight_layout()

# %%
plots.plot_residuals(df)
