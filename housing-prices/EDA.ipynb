# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plots
# %matplotlib inline
df = plots.create_date_cols('data/kc_house_data.csv')
# There are no null values in this data, and all the data is integers or floats
# except date which I converted to a datetime object
print df.columns
# Out:
# Index([u'id', u'date', u'price', u'bedrooms', u'bathrooms', u'sqft_living',
#        u'sqft_lot', u'floors', u'waterfront', u'view', u'condition', u'grade',
#        u'sqft_above', u'sqft_basement', u'yr_built', u'yr_renovated',
#        u'zipcode', u'lat', u'long', u'sqft_living15', u'sqft_lot15', u'day',
#        u'month', u'count'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119d84710>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b146e50>]], dtype=object)

# %%
pd.scatter_matrix(df.drop(['count','zipcode','sqft_lot','sqft_living','month','day','id','lat','long','sqft_basement','sqft_above'],axis=1), figsize=(20,20), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1380988d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13206f850>]], dtype=object)

# %%
fig = plt.figure(figsize=(20,20))
for i in range(0,13):
    plots.plot_daily_sales(df, i)
plt.xlabel('Month')
plt.ylabel('Number of Sales')
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
plots.plot_size_change(df)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
plt.hist(np.log(df['price']))
plt.tight_layout()

# %%
plots.plot_residuals(df)
# Out:
# ---------------------------------------------------------------------------
# MultipleInstanceError                     Traceback (most recent call last)
# <ipython-input-8-75b97f1c5384> in <module>()
# ----> 1 plots.plot_residuals(df)
#
# /Users/ChrisV/Documents/Galvanize/case-study/alumni-case-study/housing-prices/plots.py in plot_residuals(df)
#      36
#      37 def plot_residuals(df):
# ---> 38     import ipdb
#      39     ipdb.set_trace()
#      40     model = mdl.train_model(df)
#
# /Users/ChrisV/anaconda/lib/python2.7/site-packages/ipdb/__init__.py in <module>()
#       5 # https://opensource.org/licenses/BSD-3-Clause
#       6
# ----> 7 from ipdb.__main__ import set_trace, post_mortem, pm, run             # noqa
#       8 from ipdb.__main__ import runcall, runeval, launch_ipdb_on_exception  # noqa
#       9
#
# /Users/ChrisV/anaconda/lib/python2.7/site-packages/ipdb/__main__.py in <module>()
# ...
